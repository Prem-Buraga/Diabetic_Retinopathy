# %%
# !unzip /content/drive/MyDrive/aptos2019-blindness-detection.zip

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot
import cv2
import os
from tensorflow.keras.utils import img_to_array

# %%
train_dataset = pd.read_csv("/content/Dataset/train.csv")
train_dataset.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
train_dataset["diagnosis"].unique()
# Out:
# array([2, 4, 1, 0, 3])

# %%
train_dataset["diagnosis"].value_counts()
# Out:
# 0    1805
# 2     999
# 1     370
# 4     295
# 3     193
# Name: diagnosis, dtype: int64

# %%
train_dataset.shape
# Out:
# (3662, 2)

# %%
sns.countplot(x=train_dataset.diagnosis)
pyplot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset = pd.DataFrame()
dataset = dataset.append(train_dataset, ignore_index=True)
# Out:
# <ipython-input-12-67d775c578c5>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(train_dataset, ignore_index=True)

# %%
index = train_dataset[train_dataset['diagnosis'] == (2)].index.values
df_index = train_dataset.iloc[index]
# df_index = df_index.append([df_index]*1, ignore_index = True)
dataset = dataset.append(df_index, ignore_index=True)
# Out:
# <ipython-input-13-e10a76b5ba61>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(df_index, ignore_index=True)

# %%
index = train_dataset[train_dataset['diagnosis'] == (1)].index.values
df_index = train_dataset.iloc[index]
df_index = df_index.append([df_index]*3, ignore_index = True)
dataset = dataset.append(df_index, ignore_index=True)
# Out:
# <ipython-input-14-ed1a7be9ef2b>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_index = df_index.append([df_index]*3, ignore_index = True)
# <ipython-input-14-ed1a7be9ef2b>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(df_index, ignore_index=True)

# %%
index = train_dataset[train_dataset['diagnosis'] == (4)].index.values
df_index = train_dataset.iloc[index]
df_index = df_index.append([df_index]*4, ignore_index = True)
dataset = dataset.append(df_index, ignore_index=True)
# Out:
# <ipython-input-15-ba3d58016f90>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_index = df_index.append([df_index]*4, ignore_index = True)
# <ipython-input-15-ba3d58016f90>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(df_index, ignore_index=True)

# %%
index = train_dataset[train_dataset['diagnosis'] == (3)].index.values
df_index = train_dataset.iloc[index]
df_index = df_index.append([df_index]*7, ignore_index = True)
dataset = dataset.append(df_index, ignore_index=True)
# Out:
# <ipython-input-16-659e0cef41b6>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_index = df_index.append([df_index]*7, ignore_index = True)
# <ipython-input-16-659e0cef41b6>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(df_index, ignore_index=True)

# %%
dataset.diagnosis.value_counts()
# Out:
# 2    1998
# 1    1850
# 0    1805
# 4    1770
# 3    1737
# Name: diagnosis, dtype: int64

# %%
sns.countplot(x=dataset.diagnosis)
pyplot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def prepare_Images(label,path,ind):
    img=cv2.imread(path,cv2.IMREAD_COLOR)
    img_res=cv2.resize(img,(50,50))
    print(ind)
    img_array = img_to_array(img_res)
    img_array = img_array/255.0
    img_dataset.append(img_array)
    diagnosis.append(str(label))

# %%
img_dataset=[]
diagnosis = []

# %%
for i in range(len(dataset)):
    path = os.path.join('/content/Dataset/train_images','{}.png'.format(dataset.id_code[i]))
    prepare_Images(dataset.diagnosis[i],path,i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 4160
# 4161
# 4162
# 4163
# 4164
# 4165
# 4166
# 4167
# 4168
# 4169
# 4170
# 4171
# 4172
# 4173
# 4174
# 4175
# 4176
# 4177
# 4178
# 4179
# 4180
# 4181
# 4182
# 4183
# 4184
# 4185
# 4186
# 4187
# 4188
# 4189
# 4190
# 4191
# 4192
# 4193
# 4194
# 4195
# 4196
# 4197
# 4198
# 4199
# 4200
# 4201
# 4202
# 4203
# 4204
# 4205
# 4206
# 4207
# 4208
# 4209
# 4210
# 4211
# 4212
# 4213
# 4214
# 4215
# 4216
# 4217
# 4218
# 4219
# 4220
# 4221
# 4222
# 4223
# 4224
# 4225
# 4226
# 4227
# 4228
# 4229
# 4230
# 4231
# 4232
# 4233
# 4234
# 4235
# 4236
# 4237
# 4238
# 4239
# 4240
# 4241
# 4242
# 4243
# 4244
# 4245
# 4246
# 4247
# 4248
# 4249
# 4250
# 4251
# 4252
# 4253
# 4254
# 4255
# 4256
# 4257
# 4258
# 4259
# 4260
# 4261
# 4262
# 4263
# 4264
# 4265
# 4266
# 4267
# 4268
# 4269
# 4270
# 4271
# 4272
# 4273
# 4274
# 4275
# 4276
# 4277
# 4278
# 4279
# 4280
# 4281
# 4282
# 4283
# 4284
# 4285
# 4286
# 4287
# 4288
# 4289
# 4290
# 4291
# 4292
# 4293
# 4294
# 4295
# 4296
# 4297
# 4298
# 4299
# 4300
# 4301
# 4302
# 4303
# 4304
# 4305
# 4306
# 4307
# 4308
# 4309
# 4310
# 4311
# 4312
# 4313
# 4314
# 4315
# 4316
# 4317
# 4318
# 4319
# 4320
# 4321
# 4322
# 4323
# 4324
# 4325
# 4326
# 4327
# 4328
# 4329
# 4330
# 4331
# 4332
# 4333
# 4334
# 4335
# 4336
# 4337
# 4338
# 4339
# 4340
# 4341
# 4342
# 4343
# 4344
# 4345
# 4346
# 4347
# 4348
# 4349
# 4350
# 4351
# 4352
# 4353
# 4354
# 4355
# 4356
# 4357
# 4358
# 4359
# 4360
# 4361
# 4362
# 4363
# 4364
# 4365
# 4366
# 4367
# 4368
# 4369
# 4370
# 4371
# 4372
# 4373
# 4374
# 4375
# 4376
# 4377
# 4378
# 4379
# 4380
# 4381
# 4382
# 4383
# 4384
# 4385
# 4386
# 4387
# 4388
# 4389
# 4390
# 4391
# 4392
# 4393
# 4394
# 4395
# 4396
# 4397
# 4398
# 4399
# 4400
# 4401
# 4402
# 4403
# 4404
# 4405
# 4406
# 4407
# 4408
# 4409
# 4410
# 4411
# 4412
# 4413
# 4414
# 4415
# 4416
# 4417
# 4418
# 4419
# 4420
# 4421
# 4422
# 4423
# 4424
# 4425
# 4426
# 4427
# 4428
# 4429
# 4430
# 4431
# 4432
# 4433
# 4434
# 4435
# 4436
# 4437
# 4438
# 4439
# 4440
# 4441
# 4442
# 4443
# 4444
# 4445
# 4446
# 4447
# 4448
# 4449
# 4450
# 4451
# 4452
# 4453
# 4454
# 4455
# 4456
# 4457
# 4458
# 4459
# 4460
# 4461
# 4462
# 4463
# 4464
# 4465
# 4466
# 4467
# 4468
# 4469
# 4470
# 4471
# 4472
# 4473
# 4474
# 4475
# 4476
# 4477
# 4478
# 4479
# 4480
# 4481
# 4482
# 4483
# 4484
# 4485
# 4486
# 4487
# 4488
# 4489
# 4490
# 4491
# 4492
# 4493
# 4494
# 4495
# 4496
# 4497
# 4498
# 4499
# 4500
# 4501
# 4502
# 4503
# 4504
# 4505
# 4506
# 4507
# 4508
# 4509
# 4510
# 4511
# 4512
# 4513
# 4514
# 4515
# 4516
# 4517
# 4518
# 4519
# 4520
# 4521
# 4522
# 4523
# 4524
# 4525
# 4526
# 4527
# 4528
# 4529
# 4530
# 4531
# 4532
# 4533
# 4534
# 4535
# 4536
# 4537
# 4538
# 4539
# 4540
# 4541
# 4542
# 4543
# 4544
# 4545
# 4546
# 4547
# 4548
# 4549
# 4550
# 4551
# 4552
# 4553
# 4554
# 4555
# 4556
# 4557
# 4558
# 4559
# 4560
# 4561
# 4562
# 4563
# 4564
# 4565
# 4566
# 4567
# 4568
# 4569
# 4570
# 4571
# 4572
# 4573
# 4574
# 4575
# 4576
# 4577
# 4578
# 4579
# 4580
# 4581
# 4582
# 4583
# 4584
# 4585
# 4586
# 4587
# 4588
# 4589
# 4590
# 4591
# 4592
# 4593
# 4594
# 4595
# 4596
# 4597
# 4598
# 4599
# 4600
# 4601
# 4602
# 4603
# 4604
# 4605
# 4606
# 4607
# 4608
# 4609
# 4610
# 4611
# 4612
# 4613
# 4614
# 4615
# 4616
# 4617
# 4618
# 4619
# 4620
# 4621
# 4622
# 4623
# 4624
# 4625
# 4626
# 4627
# 4628
# 4629
# 4630
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# 4639
# 4640
# 4641
# 4642
# 4643
# 4644
# 4645
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656
# 4657
# 4658
# 4659
# 4660
# 4661
# 4662
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# 4669
# 4670
# 4671
# 4672
# 4673
# 4674
# 4675
# 4676
# 4677
# 4678
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4687
# 4688
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4704
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# 4712
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# 4724
# 4725
# 4726
# 4727
# 4728
# 4729
# 4730
# 4731
# 4732
# 4733
# 4734
# 4735
# 4736
# 4737
# 4738
# 4739
# 4740
# 4741
# 4742
# 4743
# 4744
# 4745
# 4746
# 4747
# 4748
# 4749
# 4750
# 4751
# 4752
# 4753
# 4754
# 4755
# 4756
# 4757
# 4758
# 4759
# 4760
# 4761
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# 4777
# 4778
# 4779
# 4780
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4898
# 4899
# 4900
# 4901
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# 4915
# 4916
# 4917
# 4918
# 4919
# 4920
# 4921
# 4922
# 4923
# 4924
# 4925
# 4926
# 4927
# 4928
# 4929
# 4930
# 4931
# 4932
# 4933
# 4934
# 4935
# 4936
# 4937
# 4938
# 4939
# 4940
# 4941
# 4942
# 4943
# 4944
# 4945
# 4946
# 4947
# 4948
# 4949
# 4950
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965
# 4966
# 4967
# 4968
# 4969
# 4970
# 4971
# 4972
# 4973
# 4974
# 4975
# 4976
# 4977
# 4978
# 4979
# 4980
# 4981
# 4982
# 4983
# 4984
# 4985
# 4986
# 4987
# 4988
# 4989
# 4990
# 4991
# 4992
# 4993
# 4994
# 4995
# 4996
# 4997
# 4998
# 4999
# 5000
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
# 5029
# 5030
# 5031
# 5032
# 5033
# 5034
# 5035
# 5036
# 5037
# 5038
# 5039
# 5040
# 5041
# 5042
# 5043
# 5044
# 5045
# 5046
# 5047
# 5048
# 5049
# 5050
# 5051
# 5052
# 5053
# 5054
# 5055
# 5056
# 5057
# 5058
# 5059
# 5060
# 5061
# 5062
# 5063
# 5064
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
# 5075
# 5076
# 5077
# 5078
# 5079
# 5080
# 5081
# 5082
# 5083
# 5084
# 5085
# 5086
# 5087
# 5088
# 5089
# 5090
# 5091
# 5092
# 5093
# 5094
# 5095
# 5096
# 5097
# 5098
# 5099
# 5100
# 5101
# 5102
# 5103
# 5104
# 5105
# 5106
# 5107
# 5108
# 5109
# 5110
# 5111
# 5112
# 5113
# 5114
# 5115
# 5116
# 5117
# 5118
# 5119
# 5120
# 5121
# 5122
# 5123
# 5124
# 5125
# 5126
# 5127
# 5128
# 5129
# 5130
# 5131
# 5132
# 5133
# 5134
# 5135
# 5136
# 5137
# 5138
# 5139
# 5140
# 5141
# 5142
# 5143
# 5144
# 5145
# 5146
# 5147
# 5148
# 5149
# 5150
# 5151
# 5152
# 5153
# 5154
# 5155
# 5156
# 5157
# 5158
# 5159
# 5160
# 5161
# 5162
# 5163
# 5164
# 5165
# 5166
# 5167
# 5168
# 5169
# 5170
# 5171
# 5172
# 5173
# 5174
# 5175
# 5176
# 5177
# 5178
# 5179
# 5180
# 5181
# 5182
# 5183
# 5184
# 5185
# 5186
# 5187
# 5188
# 5189
# 5190
# 5191
# 5192
# 5193
# 5194
# 5195
# 5196
# 5197
# 5198
# 5199
# 5200
# 5201
# 5202
# 5203
# 5204
# 5205
# 5206
# 5207
# 5208
# 5209
# 5210
# 5211
# 5212
# 5213
# 5214
# 5215
# 5216
# 5217
# 5218
# 5219
# 5220
# 5221
# 5222
# 5223
# 5224
# 5225
# 5226
# 5227
# 5228
# 5229
# 5230
# 5231
# 5232
# 5233
# 5234
# 5235
# 5236
# 5237
# 5238
# 5239
# 5240
# 5241
# 5242
# 5243
# 5244
# 5245
# 5246
# 5247
# 5248
# 5249
# 5250
# 5251
# 5252
# 5253
# 5254
# 5255
# 5256
# 5257
# 5258
# 5259
# 5260
# 5261
# 5262
# 5263
# 5264
# 5265
# 5266
# 5267
# 5268
# 5269
# 5270
# 5271
# 5272
# 5273
# 5274
# 5275
# 5276
# 5277
# 5278
# 5279
# 5280
# 5281
# 5282
# 5283
# 5284
# 5285
# 5286
# 5287
# 5288
# 5289
# 5290
# 5291
# 5292
# 5293
# 5294
# 5295
# 5296
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# 5383
# 5384
# 5385
# 5386
# 5387
# 5388
# 5389
# 5390
# 5391
# 5392
# 5393
# 5394
# 5395
# 5396
# 5397
# 5398
# 5399
# 5400
# 5401
# 5402
# 5403
# 5404
# 5405
# 5406
# 5407
# 5408
# 5409
# 5410
# 5411
# 5412
# 5413
# 5414
# 5415
# 5416
# 5417
# 5418
# 5419
# 5420
# 5421
# 5422
# 5423
# 5424
# 5425
# 5426
# 5427
# 5428
# 5429
# 5430
# 5431
# 5432
# 5433
# 5434
# 5435
# 5436
# 5437
# 5438
# 5439
# 5440
# 5441
# 5442
# 5443
# 5444
# 5445
# 5446
# 5447
# 5448
# 5449
# 5450
# 5451
# 5452
# 5453
# 5454
# 5455
# 5456
# 5457
# 5458
# 5459
# 5460
# 5461
# 5462
# 5463
# 5464
# 5465
# 5466
# 5467
# 5468
# 5469
# 5470
# 5471
# 5472
# 5473
# 5474
# 5475
# 5476
# 5477
# 5478
# 5479
# 5480
# 5481
# 5482
# 5483
# 5484
# 5485
# 5486
# 5487
# 5488
# 5489
# 5490
# 5491
# 5492
# 5493
# 5494
# 5495
# 5496
# 5497
# 5498
# 5499
# 5500
# 5501
# 5502
# 5503
# 5504
# 5505
# 5506
# 5507
# 5508
# 5509
# 5510
# 5511
# 5512
# 5513
# 5514
# 5515
# 5516
# 5517
# 5518
# 5519
# 5520
# 5521
# 5522
# 5523
# 5524
# 5525
# 5526
# 5527
# 5528
# 5529
# 5530
# 5531
# 5532
# 5533
# 5534
# 5535
# 5536
# 5537
# 5538
# 5539
# 5540
# 5541
# 5542
# 5543
# 5544
# 5545
# 5546
# 5547
# 5548
# 5549
# 5550
# 5551
# 5552
# 5553
# 5554
# 5555
# 5556
# 5557
# 5558
# 5559
# 5560
# 5561
# 5562
# 5563
# 5564
# 5565
# 5566
# 5567
# 5568
# 5569
# 5570
# 5571
# 5572
# 5573
# 5574
# 5575
# 5576
# 5577
# 5578
# 5579
# 5580
# 5581
# 5582
# 5583
# 5584
# 5585
# 5586
# 5587
# 5588
# 5589
# 5590
# 5591
# 5592
# 5593
# 5594
# 5595
# 5596
# 5597
# 5598
# 5599
# 5600
# 5601
# 5602
# 5603
# 5604
# 5605
# 5606
# 5607
# 5608
# 5609
# 5610
# 5611
# 5612
# 5613
# 5614
# 5615
# 5616
# 5617
# 5618
# 5619
# 5620
# 5621
# 5622
# 5623
# 5624
# 5625
# 5626
# 5627
# 5628
# 5629
# 5630
# 5631
# 5632
# 5633
# 5634
# 5635
# 5636
# 5637
# 5638
# 5639
# 5640
# 5641
# 5642
# 5643
# 5644
# 5645
# 5646
# 5647
# 5648
# 5649
# 5650
# 5651
# 5652
# 5653
# 5654
# 5655
# 5656
# 5657
# 5658
# 5659
# 5660
# 5661
# 5662
# 5663
# 5664
# 5665
# 5666
# 5667
# 5668
# 5669
# 5670
# 5671
# 5672
# 5673
# 5674
# 5675
# 5676
# 5677
# 5678
# 5679
# 5680
# 5681
# 5682
# 5683
# 5684
# 5685
# 5686
# 5687
# 5688
# 5689
# 5690
# 5691
# 5692
# 5693
# 5694
# 5695
# 5696
# 5697
# 5698
# 5699
# 5700
# 5701
# 5702
# 5703
# 5704
# 5705
# 5706
# 5707
# 5708
# 5709
# 5710
# 5711
# 5712
# 5713
# 5714
# 5715
# 5716
# 5717
# 5718
# 5719
# 5720
# 5721
# 5722
# 5723
# 5724
# 5725
# 5726
# 5727
# 5728
# 5729
# 5730
# 5731
# 5732
# 5733
# 5734
# 5735
# 5736
# 5737
# 5738
# 5739
# 5740
# 5741
# 5742
# 5743
# 5744
# 5745
# 5746
# 5747
# 5748
# 5749
# 5750
# 5751
# 5752
# 5753
# 5754
# 5755
# 5756
# 5757
# 5758
# 5759
# 5760
# 5761
# 5762
# 5763
# 5764
# 5765
# 5766
# 5767
# 5768
# 5769
# 5770
# 5771
# 5772
# 5773
# 5774
# 5775
# 5776
# 5777
# 5778
# 5779
# 5780
# 5781
# 5782
# 5783
# 5784
# 5785
# 5786
# 5787
# 5788
# 5789
# 5790
# 5791
# 5792
# 5793
# 5794
# 5795
# 5796
# 5797
# 5798
# 5799
# 5800
# 5801
# 5802
# 5803
# 5804
# 5805
# 5806
# 5807
# 5808
# 5809
# 5810
# 5811
# 5812
# 5813
# 5814
# 5815
# 5816
# 5817
# 5818
# 5819
# 5820
# 5821
# 5822
# 5823
# 5824
# 5825
# 5826
# 5827
# 5828
# 5829
# 5830
# 5831
# 5832
# 5833
# 5834
# 5835
# 5836
# 5837
# 5838
# 5839
# 5840
# 5841
# 5842
# 5843
# 5844
# 5845
# 5846
# 5847
# 5848
# 5849
# 5850
# 5851
# 5852
# 5853
# 5854
# 5855
# 5856
# 5857
# 5858
# 5859
# 5860
# 5861
# 5862
# 5863
# 5864
# 5865
# 5866
# 5867
# 5868
# 5869
# 5870
# 5871
# 5872
# 5873
# 5874
# 5875
# 5876
# 5877
# 5878
# 5879
# 5880
# 5881
# 5882
# 5883
# 5884
# 5885
# 5886
# 5887
# 5888
# 5889
# 5890
# 5891
# 5892
# 5893
# 5894
# 5895
# 5896
# 5897
# 5898
# 5899
# 5900
# 5901
# 5902
# 5903
# 5904
# 5905
# 5906
# 5907
# 5908
# 5909
# 5910
# 5911
# 5912
# 5913
# 5914
# 5915
# 5916
# 5917
# 5918
# 5919
# 5920
# 5921
# 5922
# 5923
# 5924
# 5925
# 5926
# 5927
# 5928
# 5929
# 5930
# 5931
# 5932
# 5933
# 5934
# 5935
# 5936
# 5937
# 5938
# 5939
# 5940
# 5941
# 5942
# 5943
# 5944
# 5945
# 5946
# 5947
# 5948
# 5949
# 5950
# 5951
# 5952
# 5953
# 5954
# 5955
# 5956
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 5965
# 5966
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5978
# 5979
# 5980
# 5981
# 5982
# 5983
# 5984
# 5985
# 5986
# 5987
# 5988
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994
# 5995
# 5996
# 5997
# 5998
# 5999
# 6000
# 6001
# 6002
# 6003
# 6004
# 6005
# 6006
# 6007
# 6008
# 6009
# 6010
# 6011
# 6012
# 6013
# 6014
# 6015
# 6016
# 6017
# 6018
# 6019
# 6020
# 6021
# 6022
# 6023
# 6024
# 6025
# 6026
# 6027
# 6028
# 6029
# 6030
# 6031
# 6032
# 6033
# 6034
# 6035
# 6036
# 6037
# 6038
# 6039
# 6040
# 6041
# 6042
# 6043
# 6044
# 6045
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058
# 6059
# 6060
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# 6072
# 6073
# 6074
# 6075
# 6076
# 6077
# 6078
# 6079
# 6080
# 6081
# 6082
# 6083
# 6084
# 6085
# 6086
# 6087
# 6088
# 6089
# 6090
# 6091
# 6092
# 6093
# 6094
# 6095
# 6096
# 6097
# 6098
# 6099
# 6100
# 6101
# 6102
# 6103
# 6104
# 6105
# 6106
# 6107
# 6108
# 6109
# 6110
# 6111
# 6112
# 6113
# 6114
# 6115
# 6116
# 6117
# 6118
# 6119
# 6120
# 6121
# 6122
# 6123
# 6124
# 6125
# 6126
# 6127
# 6128
# 6129
# 6130
# 6131
# 6132
# 6133
# 6134
# 6135
# 6136
# 6137
# 6138
# 6139
# 6140
# 6141
# 6142
# 6143
# 6144
# 6145
# 6146
# 6147
# 6148
# 6149
# 6150
# 6151
# 6152
# 6153
# 6154
# 6155
# 6156
# 6157
# 6158
# 6159
# 6160
# 6161
# 6162
# 6163
# 6164
# 6165
# 6166
# 6167
# 6168
# 6169
# 6170
# 6171
# 6172
# 6173
# 6174
# 6175
# 6176
# 6177
# 6178
# 6179
# 6180
# 6181
# 6182
# 6183
# 6184
# 6185
# 6186
# 6187
# 6188
# 6189
# 6190
# 6191
# 6192
# 6193
# 6194
# 6195
# 6196
# 6197
# 6198
# 6199
# 6200
# 6201
# 6202
# 6203
# 6204
# 6205
# 6206
# 6207
# 6208
# 6209
# 6210
# 6211
# 6212
# 6213
# 6214
# 6215
# 6216
# 6217
# 6218
# 6219
# 6220
# 6221
# 6222
# 6223
# 6224
# 6225
# 6226
# 6227
# 6228
# 6229
# 6230
# 6231
# 6232
# 6233
# 6234
# 6235
# 6236
# 6237
# 6238
# 6239
# 6240
# 6241
# 6242
# 6243
# 6244
# 6245
# 6246
# 6247
# 6248
# 6249
# 6250
# 6251
# 6252
# 6253
# 6254
# 6255
# 6256
# 6257
# 6258
# 6259
# 6260
# 6261
# 6262
# 6263
# 6264
# 6265
# 6266
# 6267
# 6268
# 6269
# 6270
# 6271
# 6272
# 6273
# 6274
# 6275
# 6276
# 6277
# 6278
# 6279
# 6280
# 6281
# 6282
# 6283
# 6284
# 6285
# 6286
# 6287
# 6288
# 6289
# 6290
# 6291
# 6292
# 6293
# 6294
# 6295
# 6296
# 6297
# 6298
# 6299
# 6300
# 6301
# 6302
# 6303
# 6304
# 6305
# 6306
# 6307
# 6308
# 6309
# 6310
# 6311
# 6312
# 6313
# 6314
# 6315
# 6316
# 6317
# 6318
# 6319
# 6320
# 6321
# 6322
# 6323
# 6324
# 6325
# 6326
# 6327
# 6328
# 6329
# 6330
# 6331
# 6332
# 6333
# 6334
# 6335
# 6336
# 6337
# 6338
# 6339
# 6340
# 6341
# 6342
# 6343
# 6344
# 6345
# 6346
# 6347
# 6348
# 6349
# 6350
# 6351
# 6352
# 6353
# 6354
# 6355
# 6356
# 6357
# 6358
# 6359
# 6360
# 6361
# 6362
# 6363
# 6364
# 6365
# 6366
# 6367
# 6368
# 6369
# 6370
# 6371
# 6372
# 6373
# 6374
# 6375
# 6376
# 6377
# 6378
# 6379
# 6380
# 6381
# 6382
# 6383
# 6384
# 6385
# 6386
# 6387
# 6388
# 6389
# 6390
# 6391
# 6392
# 6393
# 6394
# 6395
# 6396
# 6397
# 6398
# 6399
# 6400
# 6401
# 6402
# 6403
# 6404
# 6405
# 6406
# 6407
# 6408
# 6409
# 6410
# 6411
# 6412
# 6413
# 6414
# 6415
# 6416
# 6417
# 6418
# 6419
# 6420
# 6421
# 6422
# 6423
# 6424
# 6425
# 6426
# 6427
# 6428
# 6429
# 6430
# 6431
# 6432
# 6433
# 6434
# 6435
# 6436
# 6437
# 6438
# 6439
# 6440
# 6441
# 6442
# 6443
# 6444
# 6445
# 6446
# 6447
# 6448
# 6449
# 6450
# 6451
# 6452
# 6453
# 6454
# 6455
# 6456
# 6457
# 6458
# 6459
# 6460
# 6461
# 6462
# 6463
# 6464
# 6465
# 6466
# 6467
# 6468
# 6469
# 6470
# 6471
# 6472
# 6473
# 6474
# 6475
# 6476
# 6477
# 6478
# 6479
# 6480
# 6481
# 6482
# 6483
# 6484
# 6485
# 6486
# 6487
# 6488
# 6489
# 6490
# 6491
# 6492
# 6493
# 6494
# 6495
# 6496
# 6497
# 6498
# 6499
# 6500
# 6501
# 6502
# 6503
# 6504
# 6505
# 6506
# 6507
# 6508
# 6509
# 6510
# 6511
# 6512
# 6513
# 6514
# 6515
# 6516
# 6517
# 6518
# 6519
# 6520
# 6521
# 6522
# 6523
# 6524
# 6525
# 6526
# 6527
# 6528
# 6529
# 6530
# 6531
# 6532
# 6533
# 6534
# 6535
# 6536
# 6537
# 6538
# 6539
# 6540
# 6541
# 6542
# 6543
# 6544
# 6545
# 6546
# 6547
# 6548
# 6549
# 6550
# 6551
# 6552
# 6553
# 6554
# 6555
# 6556
# 6557
# 6558
# 6559
# 6560
# 6561
# 6562
# 6563
# 6564
# 6565
# 6566
# 6567
# 6568
# 6569
# 6570
# 6571
# 6572
# 6573
# 6574
# 6575
# 6576
# 6577
# 6578
# 6579
# 6580
# 6581
# 6582
# 6583
# 6584
# 6585
# 6586
# 6587
# 6588
# 6589
# 6590
# 6591
# 6592
# 6593
# 6594
# 6595
# 6596
# 6597
# 6598
# 6599
# 6600
# 6601
# 6602
# 6603
# 6604
# 6605
# 6606
# 6607
# 6608
# 6609
# 6610
# 6611
# 6612
# 6613
# 6614
# 6615
# 6616
# 6617
# 6618
# 6619
# 6620
# 6621
# 6622
# 6623
# 6624
# 6625
# 6626
# 6627
# 6628
# 6629
# 6630
# 6631
# 6632
# 6633
# 6634
# 6635
# 6636
# 6637
# 6638
# 6639
# 6640
# 6641
# 6642
# 6643
# 6644
# 6645
# 6646
# 6647
# 6648
# 6649
# 6650
# 6651
# 6652
# 6653
# 6654
# 6655
# 6656
# 6657
# 6658
# 6659
# 6660
# 6661
# 6662
# 6663
# 6664
# 6665
# 6666
# 6667
# 6668
# 6669
# 6670
# 6671
# 6672
# 6673
# 6674
# 6675
# 6676
# 6677
# 6678
# 6679
# 6680
# 6681
# 6682
# 6683
# 6684
# 6685
# 6686
# 6687
# 6688
# 6689
# 6690
# 6691
# 6692
# 6693
# 6694
# 6695
# 6696
# 6697
# 6698
# 6699
# 6700
# 6701
# 6702
# 6703
# 6704
# 6705
# 6706
# 6707
# 6708
# 6709
# 6710
# 6711
# 6712
# 6713
# 6714
# 6715
# 6716
# 6717
# 6718
# 6719
# 6720
# 6721
# 6722
# 6723
# 6724
# 6725
# 6726
# 6727
# 6728
# 6729
# 6730
# 6731
# 6732
# 6733
# 6734
# 6735
# 6736
# 6737
# 6738
# 6739
# 6740
# 6741
# 6742
# 6743
# 6744
# 6745
# 6746
# 6747
# 6748
# 6749
# 6750
# 6751
# 6752
# 6753
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# 6762
# 6763
# 6764
# 6765
# 6766
# 6767
# 6768
# 6769
# 6770
# 6771
# 6772
# 6773
# 6774
# 6775
# 6776
# 6777
# 6778
# 6779
# 6780
# 6781
# 6782
# 6783
# 6784
# 6785
# 6786
# 6787
# 6788
# 6789
# 6790
# 6791
# 6792
# 6793
# 6794
# 6795
# 6796
# 6797
# 6798
# 6799
# 6800
# 6801
# 6802
# 6803
# 6804
# 6805
# 6806
# 6807
# 6808
# 6809
# 6810
# 6811
# 6812
# 6813
# 6814
# 6815
# 6816
# 6817
# 6818
# 6819
# 6820
# 6821
# 6822
# 6823
# 6824
# 6825
# 6826
# 6827
# 6828
# 6829
# 6830
# 6831
# 6832
# 6833
# 6834
# 6835
# 6836
# 6837
# 6838
# 6839
# 6840
# 6841
# 6842
# 6843
# 6844
# 6845
# 6846
# 6847
# 6848
# 6849
# 6850
# 6851
# 6852
# 6853
# 6854
# 6855
# 6856
# 6857
# 6858
# 6859
# 6860
# 6861
# 6862
# 6863
# 6864
# 6865
# 6866
# 6867
# 6868
# 6869
# 6870
# 6871
# 6872
# 6873
# 6874
# 6875
# 6876
# 6877
# 6878
# 6879
# 6880
# 6881
# 6882
# 6883
# 6884
# 6885
# 6886
# 6887
# 6888
# 6889
# 6890
# 6891
# 6892
# 6893
# 6894
# 6895
# 6896
# 6897
# 6898
# 6899
# 6900
# 6901
# 6902
# 6903
# 6904
# 6905
# 6906
# 6907
# 6908
# 6909
# 6910
# 6911
# 6912
# 6913
# 6914
# 6915
# 6916
# 6917
# 6918
# 6919
# 6920
# 6921
# 6922
# 6923
# 6924
# 6925
# 6926
# 6927
# 6928
# 6929
# 6930
# 6931
# 6932
# 6933
# 6934
# 6935
# 6936
# 6937
# 6938
# 6939
# 6940
# 6941
# 6942
# 6943
# 6944
# 6945
# 6946
# 6947
# 6948
# 6949
# 6950
# 6951
# 6952
# 6953
# 6954
# 6955
# 6956
# 6957
# 6958
# 6959
# 6960
# 6961
# 6962
# 6963
# 6964
# 6965
# 6966
# 6967
# 6968
# 6969
# 6970
# 6971
# 6972
# 6973
# 6974
# 6975
# 6976
# 6977
# 6978
# 6979
# 6980
# 6981
# 6982
# 6983
# 6984
# 6985
# 6986
# 6987
# 6988
# 6989
# 6990
# 6991
# 6992
# 6993
# 6994
# 6995
# 6996
# 6997
# 6998
# 6999
# 7000
# 7001
# 7002
# 7003
# 7004
# 7005
# 7006
# 7007
# 7008
# 7009
# 7010
# 7011
# 7012
# 7013
# 7014
# 7015
# 7016
# 7017
# 7018
# 7019
# 7020
# 7021
# 7022
# 7023
# 7024
# 7025
# 7026
# 7027
# 7028
# 7029
# 7030
# 7031
# 7032
# 7033
# 7034
# 7035
# 7036
# 7037
# 7038
# 7039
# 7040
# 7041
# 7042
# 7043
# 7044
# 7045
# 7046
# 7047
# 7048
# 7049
# 7050
# 7051
# 7052
# 7053
# 7054
# 7055
# 7056
# 7057
# 7058
# 7059
# 7060
# 7061
# 7062
# 7063
# 7064
# 7065
# 7066
# 7067
# 7068
# 7069
# 7070
# 7071
# 7072
# 7073
# 7074
# 7075
# 7076
# 7077
# 7078
# 7079
# 7080
# 7081
# 7082
# 7083
# 7084
# 7085
# 7086
# 7087
# 7088
# 7089
# 7090
# 7091
# 7092
# 7093
# 7094
# 7095
# 7096
# 7097
# 7098
# 7099
# 7100
# 7101
# 7102
# 7103
# 7104
# 7105
# 7106
# 7107
# 7108
# 7109
# 7110
# 7111
# 7112
# 7113
# 7114
# 7115
# 7116
# 7117
# 7118
# 7119
# 7120
# 7121
# 7122
# 7123
# 7124
# 7125
# 7126
# 7127
# 7128
# 7129
# 7130
# 7131
# 7132
# 7133
# 7134
# 7135
# 7136
# 7137
# 7138
# 7139
# 7140
# 7141
# 7142
# 7143
# 7144
# 7145
# 7146
# 7147
# 7148
# 7149
# 7150
# 7151
# 7152
# 7153
# 7154
# 7155
# 7156
# 7157
# 7158
# 7159
# 7160
# 7161
# 7162
# 7163
# 7164
# 7165
# 7166
# 7167
# 7168
# 7169
# 7170
# 7171
# 7172
# 7173
# 7174
# 7175
# 7176
# 7177
# 7178
# 7179
# 7180
# 7181
# 7182
# 7183
# 7184
# 7185
# 7186
# 7187
# 7188
# 7189
# 7190
# 7191
# 7192
# 7193
# 7194
# 7195
# 7196
# 7197
# 7198
# 7199
# 7200
# 7201
# 7202
# 7203
# 7204
# 7205
# 7206
# 7207
# 7208
# 7209
# 7210
# 7211
# 7212
# 7213
# 7214
# 7215
# 7216
# 7217
# 7218
# 7219
# 7220
# 7221
# 7222
# 7223
# 7224
# 7225
# 7226
# 7227
# 7228
# 7229
# 7230
# 7231
# 7232
# 7233
# 7234
# 7235
# 7236
# 7237
# 7238
# 7239
# 7240
# 7241
# 7242
# 7243
# 7244
# 7245
# 7246
# 7247
# 7248
# 7249
# 7250
# 7251
# 7252
# 7253
# 7254
# 7255
# 7256
# 7257
# 7258
# 7259
# 7260
# 7261
# 7262
# 7263
# 7264
# 7265
# 7266
# 7267
# 7268
# 7269
# 7270
# 7271
# 7272
# 7273
# 7274
# 7275
# 7276
# 7277
# 7278
# 7279
# 7280
# 7281
# 7282
# 7283
# 7284
# 7285
# 7286
# 7287
# 7288
# 7289
# 7290
# 7291
# 7292
# 7293
# 7294
# 7295
# 7296
# 7297
# 7298
# 7299
# 7300
# 7301
# 7302
# 7303
# 7304
# 7305
# 7306
# 7307
# 7308
# 7309
# 7310
# 7311
# 7312
# 7313
# 7314
# 7315
# 7316
# 7317
# 7318
# 7319
# 7320
# 7321
# 7322
# 7323
# 7324
# 7325
# 7326
# 7327
# 7328
# 7329
# 7330
# 7331
# 7332
# 7333
# 7334
# 7335
# 7336
# 7337
# 7338
# 7339
# 7340
# 7341
# 7342
# 7343
# 7344
# 7345
# 7346
# 7347
# 7348
# 7349
# 7350
# 7351
# 7352
# 7353
# 7354
# 7355
# 7356
# 7357
# 7358
# 7359
# 7360
# 7361
# 7362
# 7363
# 7364
# 7365
# 7366
# 7367
# 7368
# 7369
# 7370
# 7371
# 7372
# 7373
# 7374
# 7375
# 7376
# 7377
# 7378
# 7379
# 7380
# 7381
# 7382
# 7383
# 7384
# 7385
# 7386
# 7387
# 7388
# 7389
# 7390
# 7391
# 7392
# 7393
# 7394
# 7395
# 7396
# 7397
# 7398
# 7399
# 7400
# 7401
# 7402
# 7403
# 7404
# 7405
# 7406
# 7407
# 7408
# 7409
# 7410
# 7411
# 7412
# 7413
# 7414
# 7415
# 7416
# 7417
# 7418
# 7419
# 7420
# 7421
# 7422
# 7423
# 7424
# 7425
# 7426
# 7427
# 7428
# 7429
# 7430
# 7431
# 7432
# 7433
# 7434
# 7435
# 7436
# 7437
# 7438
# 7439
# 7440
# 7441
# 7442
# 7443
# 7444
# 7445
# 7446
# 7447
# 7448
# 7449
# 7450
# 7451
# 7452
# 7453
# 7454
# 7455
# 7456
# 7457
# 7458
# 7459
# 7460
# 7461
# 7462
# 7463
# 7464
# 7465
# 7466
# 7467
# 7468
# 7469
# 7470
# 7471
# 7472
# 7473
# 7474
# 7475
# 7476
# 7477
# 7478
# 7479
# 7480
# 7481
# 7482
# 7483
# 7484
# 7485
# 7486
# 7487
# 7488
# 7489
# 7490
# 7491
# 7492
# 7493
# 7494
# 7495
# 7496
# 7497
# 7498
# 7499
# 7500
# 7501
# 7502
# 7503
# 7504
# 7505
# 7506
# 7507
# 7508
# 7509
# 7510
# 7511
# 7512
# 7513
# 7514
# 7515
# 7516
# 7517
# 7518
# 7519
# 7520
# 7521
# 7522
# 7523
# 7524
# 7525
# 7526
# 7527
# 7528
# 7529
# 7530
# 7531
# 7532
# 7533
# 7534
# 7535
# 7536
# 7537
# 7538
# 7539
# 7540
# 7541
# 7542
# 7543
# 7544
# 7545
# 7546
# 7547
# 7548
# 7549
# 7550
# 7551
# 7552
# 7553
# 7554
# 7555
# 7556
# 7557
# 7558
# 7559
# 7560
# 7561
# 7562
# 7563
# 7564
# 7565
# 7566
# 7567
# 7568
# 7569
# 7570
# 7571
# 7572
# 7573
# 7574
# 7575
# 7576
# 7577
# 7578
# 7579
# 7580
# 7581
# 7582
# 7583
# 7584
# 7585
# 7586
# 7587
# 7588
# 7589
# 7590
# 7591
# 7592
# 7593
# 7594
# 7595
# 7596
# 7597
# 7598
# 7599
# 7600
# 7601
# 7602
# 7603
# 7604
# 7605
# 7606
# 7607
# 7608
# 7609
# 7610
# 7611
# 7612
# 7613
# 7614
# 7615
# 7616
# 7617
# 7618
# 7619
# 7620
# 7621
# 7622
# 7623
# 7624
# 7625
# 7626
# 7627
# 7628
# 7629
# 7630
# 7631
# 7632
# 7633
# 7634
# 7635
# 7636
# 7637
# 7638
# 7639
# 7640
# 7641
# 7642
# 7643
# 7644
# 7645
# 7646
# 7647
# 7648
# 7649
# 7650
# 7651
# 7652
# 7653
# 7654
# 7655
# 7656
# 7657
# 7658
# 7659
# 7660
# 7661
# 7662
# 7663
# 7664
# 7665
# 7666
# 7667
# 7668
# 7669
# 7670
# 7671
# 7672
# 7673
# 7674
# 7675
# 7676
# 7677
# 7678
# 7679
# 7680
# 7681
# 7682
# 7683
# 7684
# 7685
# 7686
# 7687
# 7688
# 7689
# 7690
# 7691
# 7692
# 7693
# 7694
# 7695
# 7696
# 7697
# 7698
# 7699
# 7700
# 7701
# 7702
# 7703
# 7704
# 7705
# 7706
# 7707
# 7708
# 7709
# 7710
# 7711
# 7712
# 7713
# 7714
# 7715
# 7716
# 7717
# 7718
# 7719
# 7720
# 7721
# 7722
# 7723
# 7724
# 7725
# 7726
# 7727
# 7728
# 7729
# 7730
# 7731
# 7732
# 7733
# 7734
# 7735
# 7736
# 7737
# 7738
# 7739
# 7740
# 7741
# 7742
# 7743
# 7744
# 7745
# 7746
# 7747
# 7748
# 7749
# 7750
# 7751
# 7752
# 7753
# 7754
# 7755
# 7756
# 7757
# 7758
# 7759
# 7760
# 7761
# 7762
# 7763
# 7764
# 7765
# 7766
# 7767
# 7768
# 7769
# 7770
# 7771
# 7772
# 7773
# 7774
# 7775
# 7776
# 7777
# 7778
# 7779
# 7780
# 7781
# 7782
# 7783
# 7784
# 7785
# 7786
# 7787
# 7788
# 7789
# 7790
# 7791
# 7792
# 7793
# 7794
# 7795
# 7796
# 7797
# 7798
# 7799
# 7800
# 7801
# 7802
# 7803
# 7804
# 7805
# 7806
# 7807
# 7808
# 7809
# 7810
# 7811
# 7812
# 7813
# 7814
# 7815
# 7816
# 7817
# 7818
# 7819
# 7820
# 7821
# 7822
# 7823
# 7824
# 7825
# 7826
# 7827
# 7828
# 7829
# 7830
# 7831
# 7832
# 7833
# 7834
# 7835
# 7836
# 7837
# 7838
# 7839
# 7840
# 7841
# 7842
# 7843
# 7844
# 7845
# 7846
# 7847
# 7848
# 7849
# 7850
# 7851
# 7852
# 7853
# 7854
# 7855
# 7856
# 7857
# 7858
# 7859
# 7860
# 7861
# 7862
# 7863
# 7864
# 7865
# 7866
# 7867
# 7868
# 7869
# 7870
# 7871
# 7872
# 7873
# 7874
# 7875
# 7876
# 7877
# 7878
# 7879
# 7880
# 7881
# 7882
# 7883
# 7884
# 7885
# 7886
# 7887
# 7888
# 7889
# 7890
# 7891
# 7892
# 7893
# 7894
# 7895
# 7896
# 7897
# 7898
# 7899
# 7900
# 7901
# 7902
# 7903
# 7904
# 7905
# 7906
# 7907
# 7908
# 7909
# 7910
# 7911
# 7912
# 7913
# 7914
# 7915
# 7916
# 7917
# 7918
# 7919
# 7920
# 7921
# 7922
# 7923
# 7924
# 7925
# 7926
# 7927
# 7928
# 7929
# 7930
# 7931
# 7932
# 7933
# 7934
# 7935
# 7936
# 7937
# 7938
# 7939
# 7940
# 7941
# 7942
# 7943
# 7944
# 7945
# 7946
# 7947
# 7948
# 7949
# 7950
# 7951
# 7952
# 7953
# 7954
# 7955
# 7956
# 7957
# 7958
# 7959
# 7960
# 7961
# 7962
# 7963
# 7964
# 7965
# 7966
# 7967
# 7968
# 7969
# 7970
# 7971
# 7972
# 7973
# 7974
# 7975
# 7976
# 7977
# 7978
# 7979
# 7980
# 7981
# 7982
# 7983
# 7984
# 7985
# 7986
# 7987
# 7988
# 7989
# 7990
# 7991
# 7992
# 7993
# 7994
# 7995
# 7996
# 7997
# 7998
# 7999
# 8000
# 8001
# 8002
# 8003
# 8004
# 8005
# 8006
# 8007
# 8008
# 8009
# 8010
# 8011
# 8012
# 8013
# 8014
# 8015
# 8016
# 8017
# 8018
# 8019
# 8020
# 8021
# 8022
# 8023
# 8024
# 8025
# 8026
# 8027
# 8028
# 8029
# 8030
# 8031
# 8032
# 8033
# 8034
# 8035
# 8036
# 8037
# 8038
# 8039
# 8040
# 8041
# 8042
# 8043
# 8044
# 8045
# 8046
# 8047
# 8048
# 8049
# 8050
# 8051
# 8052
# 8053
# 8054
# 8055
# 8056
# 8057
# 8058
# 8059
# 8060
# 8061
# 8062
# 8063
# 8064
# 8065
# 8066
# 8067
# 8068
# 8069
# 8070
# 8071
# 8072
# 8073
# 8074
# 8075
# 8076
# 8077
# 8078
# 8079
# 8080
# 8081
# 8082
# 8083
# 8084
# 8085
# 8086
# 8087
# 8088
# 8089
# 8090
# 8091
# 8092
# 8093
# 8094
# 8095
# 8096
# 8097
# 8098
# 8099
# 8100
# 8101
# 8102
# 8103
# 8104
# 8105
# 8106
# 8107
# 8108
# 8109
# 8110
# 8111
# 8112
# 8113
# 8114
# 8115
# 8116
# 8117
# 8118
# 8119
# 8120
# 8121
# 8122
# 8123
# 8124
# 8125
# 8126
# 8127
# 8128
# 8129
# 8130
# 8131
# 8132
# 8133
# 8134
# 8135
# 8136
# 8137
# 8138
# 8139
# 8140
# 8141
# 8142
# 8143
# 8144
# 8145
# 8146
# 8147
# 8148
# 8149
# 8150
# 8151
# 8152
# 8153
# 8154
# 8155
# 8156
# 8157
# 8158
# 8159
# 8160
# 8161
# 8162
# 8163
# 8164
# 8165
# 8166
# 8167
# 8168
# 8169
# 8170
# 8171
# 8172
# 8173
# 8174
# 8175
# 8176
# 8177
# 8178
# 8179
# 8180
# 8181
# 8182
# 8183
# 8184
# 8185
# 8186
# 8187
# 8188
# 8189
# 8190
# 8191
# 8192
# 8193
# 8194
# 8195
# 8196
# 8197
# 8198
# 8199
# 8200
# 8201
# 8202
# 8203
# 8204
# 8205
# 8206
# 8207
# 8208
# 8209
# 8210
# 8211
# 8212
# 8213
# 8214
# 8215
# 8216
# 8217
# 8218
# 8219
# 8220
# 8221
# 8222
# 8223
# 8224
# 8225
# 8226
# 8227
# 8228
# 8229
# 8230
# 8231
# 8232
# 8233
# 8234
# 8235
# 8236
# 8237
# 8238
# 8239
# 8240
# 8241
# 8242
# 8243
# 8244
# 8245
# 8246
# 8247
# 8248
# 8249
# 8250
# 8251
# 8252
# 8253
# 8254
# 8255
# 8256
# 8257
# 8258
# 8259
# 8260
# 8261
# 8262
# 8263
# 8264
# 8265
# 8266
# 8267
# 8268
# 8269
# 8270
# 8271
# 8272
# 8273
# 8274
# 8275
# 8276
# 8277
# 8278
# 8279
# 8280
# 8281
# 8282
# 8283
# 8284
# 8285
# 8286
# 8287
# 8288
# 8289
# 8290
# 8291
# 8292
# 8293
# 8294
# 8295
# 8296
# 8297
# 8298
# 8299
# 8300
# 8301
# 8302
# 8303
# 8304
# 8305
# 8306
# 8307
# 8308
# 8309
# 8310
# 8311
# 8312
# 8313
# 8314
# 8315
# 8316
# 8317
# 8318
# 8319
# 8320
# 8321
# 8322
# 8323
# 8324
# 8325
# 8326
# 8327
# 8328
# 8329
# 8330
# 8331
# 8332
# 8333
# 8334
# 8335
# 8336
# 8337
# 8338
# 8339
# 8340
# 8341
# 8342
# 8343
# 8344
# 8345
# 8346
# 8347
# 8348
# 8349
# 8350
# 8351
# 8352
# 8353
# 8354
# 8355
# 8356
# 8357
# 8358
# 8359
# 8360
# 8361
# 8362
# 8363
# 8364
# 8365
# 8366
# 8367
# 8368
# 8369
# 8370
# 8371
# 8372
# 8373
# 8374
# 8375
# 8376
# 8377
# 8378
# 8379
# 8380
# 8381
# 8382
# 8383
# 8384
# 8385
# 8386
# 8387
# 8388
# 8389
# 8390
# 8391
# 8392
# 8393
# 8394
# 8395
# 8396
# 8397
# 8398
# 8399
# 8400
# 8401
# 8402
# 8403
# 8404
# 8405
# 8406
# 8407
# 8408
# 8409
# 8410
# 8411
# 8412
# 8413
# 8414
# 8415
# 8416
# 8417
# 8418
# 8419
# 8420
# 8421
# 8422
# 8423
# 8424
# 8425
# 8426
# 8427
# 8428
# 8429
# 8430
# 8431
# 8432
# 8433
# 8434
# 8435
# 8436
# 8437
# 8438
# 8439
# 8440
# 8441
# 8442
# 8443
# 8444
# 8445
# 8446
# 8447
# 8448
# 8449
# 8450
# 8451
# 8452
# 8453
# 8454
# 8455
# 8456
# 8457
# 8458
# 8459
# 8460
# 8461
# 8462
# 8463
# 8464
# 8465
# 8466
# 8467
# 8468
# 8469
# 8470
# 8471
# 8472
# 8473
# 8474
# 8475
# 8476
# 8477
# 8478
# 8479
# 8480
# 8481
# 8482
# 8483
# 8484
# 8485
# 8486
# 8487
# 8488
# 8489
# 8490
# 8491
# 8492
# 8493
# 8494
# 8495
# 8496
# 8497
# 8498
# 8499
# 8500
# 8501
# 8502
# 8503
# 8504
# 8505
# 8506
# 8507
# 8508
# 8509
# 8510
# 8511
# 8512
# 8513
# 8514
# 8515
# 8516
# 8517
# 8518
# 8519
# 8520
# 8521
# 8522
# 8523
# 8524
# 8525
# 8526
# 8527
# 8528
# 8529
# 8530
# 8531
# 8532
# 8533
# 8534
# 8535
# 8536
# 8537
# 8538
# 8539
# 8540
# 8541
# 8542
# 8543
# 8544
# 8545
# 8546
# 8547
# 8548
# 8549
# 8550
# 8551
# 8552
# 8553
# 8554
# 8555
# 8556
# 8557
# 8558
# 8559
# 8560
# 8561
# 8562
# 8563
# 8564
# 8565
# 8566
# 8567
# 8568
# 8569
# 8570
# 8571
# 8572
# 8573
# 8574
# 8575
# 8576
# 8577
# 8578
# 8579
# 8580
# 8581
# 8582
# 8583
# 8584
# 8585
# 8586
# 8587
# 8588
# 8589
# 8590
# 8591
# 8592
# 8593
# 8594
# 8595
# 8596
# 8597
# 8598
# 8599
# 8600
# 8601
# 8602
# 8603
# 8604
# 8605
# 8606
# 8607
# 8608
# 8609
# 8610
# 8611
# 8612
# 8613
# 8614
# 8615
# 8616
# 8617
# 8618
# 8619
# 8620
# 8621
# 8622
# 8623
# 8624
# 8625
# 8626
# 8627
# 8628
# 8629
# 8630
# 8631
# 8632
# 8633
# 8634
# 8635
# 8636
# 8637
# 8638
# 8639
# 8640
# 8641
# 8642
# 8643
# 8644
# 8645
# 8646
# 8647
# 8648
# 8649
# 8650
# 8651
# 8652
# 8653
# 8654
# 8655
# 8656
# 8657
# 8658
# 8659
# 8660
# 8661
# 8662
# 8663
# 8664
# 8665
# 8666
# 8667
# 8668
# 8669
# 8670
# 8671
# 8672
# 8673
# 8674
# 8675
# 8676
# 8677
# 8678
# 8679
# 8680
# 8681
# 8682
# 8683
# 8684
# 8685
# 8686
# 8687
# 8688
# 8689
# 8690
# 8691
# 8692
# 8693
# 8694
# 8695
# 8696
# 8697
# 8698
# 8699
# 8700
# 8701
# 8702
# 8703
# 8704
# 8705
# 8706
# 8707
# 8708
# 8709
# 8710
# 8711
# 8712
# 8713
# 8714
# 8715
# 8716
# 8717
# 8718
# 8719
# 8720
# 8721
# 8722
# 8723
# 8724
# 8725
# 8726
# 8727
# 8728
# 8729
# 8730
# 8731
# 8732
# 8733
# 8734
# 8735
# 8736
# 8737
# 8738
# 8739
# 8740
# 8741
# 8742
# 8743
# 8744
# 8745
# 8746
# 8747
# 8748
# 8749
# 8750
# 8751
# 8752
# 8753
# 8754
# 8755
# 8756
# 8757
# 8758
# 8759
# 8760
# 8761
# 8762
# 8763
# 8764
# 8765
# 8766
# 8767
# 8768
# 8769
# 8770
# 8771
# 8772
# 8773
# 8774
# 8775
# 8776
# 8777
# 8778
# 8779
# 8780
# 8781
# 8782
# 8783
# 8784
# 8785
# 8786
# 8787
# 8788
# 8789
# 8790
# 8791
# 8792
# 8793
# 8794
# 8795
# 8796
# 8797
# 8798
# 8799
# 8800
# 8801
# 8802
# 8803
# 8804
# 8805
# 8806
# 8807
# 8808
# 8809
# 8810
# 8811
# 8812
# 8813
# 8814
# 8815
# 8816
# 8817
# 8818
# 8819
# 8820
# 8821
# 8822
# 8823
# 8824
# 8825
# 8826
# 8827
# 8828
# 8829
# 8830
# 8831
# 8832
# 8833
# 8834
# 8835
# 8836
# 8837
# 8838
# 8839
# 8840
# 8841
# 8842
# 8843
# 8844
# 8845
# 8846
# 8847
# 8848
# 8849
# 8850
# 8851
# 8852
# 8853
# 8854
# 8855
# 8856
# 8857
# 8858
# 8859
# 8860
# 8861
# 8862
# 8863
# 8864
# 8865
# 8866
# 8867
# 8868
# 8869
# 8870
# 8871
# 8872
# 8873
# 8874
# 8875
# 8876
# 8877
# 8878
# 8879
# 8880
# 8881
# 8882
# 8883
# 8884
# 8885
# 8886
# 8887
# 8888
# 8889
# 8890
# 8891
# 8892
# 8893
# 8894
# 8895
# 8896
# 8897
# 8898
# 8899
# 8900
# 8901
# 8902
# 8903
# 8904
# 8905
# 8906
# 8907
# 8908
# 8909
# 8910
# 8911
# 8912
# 8913
# 8914
# 8915
# 8916
# 8917
# 8918
# 8919
# 8920
# 8921
# 8922
# 8923
# 8924
# 8925
# 8926
# 8927
# 8928
# 8929
# 8930
# 8931
# 8932
# 8933
# 8934
# 8935
# 8936
# 8937
# 8938
# 8939
# 8940
# 8941
# 8942
# 8943
# 8944
# 8945
# 8946
# 8947
# 8948
# 8949
# 8950
# 8951
# 8952
# 8953
# 8954
# 8955
# 8956
# 8957
# 8958
# 8959
# 8960
# 8961
# 8962
# 8963
# 8964
# 8965
# 8966
# 8967
# 8968
# 8969
# 8970
# 8971
# 8972
# 8973
# 8974
# 8975
# 8976
# 8977
# 8978
# 8979
# 8980
# 8981
# 8982
# 8983
# 8984
# 8985
# 8986
# 8987
# 8988
# 8989
# 8990
# 8991
# 8992
# 8993
# 8994
# 8995
# 8996
# 8997
# 8998
# 8999
# 9000
# 9001
# 9002
# 9003
# 9004
# 9005
# 9006
# 9007
# 9008
# 9009
# 9010
# 9011
# 9012
# 9013
# 9014
# 9015
# 9016
# 9017
# 9018
# 9019
# 9020
# 9021
# 9022
# 9023
# 9024
# 9025
# 9026
# 9027
# 9028
# 9029
# 9030
# 9031
# 9032
# 9033
# 9034
# 9035
# 9036
# 9037
# 9038
# 9039
# 9040
# 9041
# 9042
# 9043
# 9044
# 9045
# 9046
# 9047
# 9048
# 9049
# 9050
# 9051
# 9052
# 9053
# 9054
# 9055
# 9056
# 9057
# 9058
# 9059
# 9060
# 9061
# 9062
# 9063
# 9064
# 9065
# 9066
# 9067
# 9068
# 9069
# 9070
# 9071
# 9072
# 9073
# 9074
# 9075
# 9076
# 9077
# 9078
# 9079
# 9080
# 9081
# 9082
# 9083
# 9084
# 9085
# 9086
# 9087
# 9088
# 9089
# 9090
# 9091
# 9092
# 9093
# 9094
# 9095
# 9096
# 9097
# 9098
# 9099
# 9100
# 9101
# 9102
# 9103
# 9104
# 9105
# 9106
# 9107
# 9108
# 9109
# 9110
# 9111
# 9112
# 9113
# 9114
# 9115
# 9116
# 9117
# 9118
# 9119
# 9120
# 9121
# 9122
# 9123
# 9124
# 9125
# 9126
# 9127
# 9128
# 9129
# 9130
# 9131
# 9132
# 9133
# 9134
# 9135
# 9136
# 9137
# 9138
# 9139
# 9140
# 9141
# 9142
# 9143
# 9144
# 9145
# 9146
# 9147
# 9148
# 9149
# 9150
# 9151
# 9152
# 9153
# 9154
# 9155
# 9156
# 9157
# 9158
# 9159

# %%
def display_samples(df, columns=3, rows=3):
    fig=pyplot.figure(figsize=(5*columns, 4*rows))

    for i in range(columns*rows):
        image_path = os.path.join('/content/Dataset/train_images','{}.png'.format(df.id_code[i]))
        image_id = df.diagnosis[i]
        img = cv2.imread(f'{image_path}')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        #img = crop_image_from_gray(img)
        img = cv2.resize(img, (224,224))
#         img = cv2.addWeighted(img,4,cv2.GaussianBlur(img, (0,0), 224/40) ,-4 ,128)

        fig.add_subplot(rows, columns, i+1)
        pyplot.title(image_id)
        pyplot.imshow(img)

    pyplot.tight_layout()

display_samples(dataset)

# %%
imgs = np.array(img_dataset)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

le = LabelEncoder()
diag = le.fit_transform(dataset.diagnosis)
diag = to_categorical(diag)
print(diag.shape)
# Out:
# (9160, 5)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(imgs, diag,
                                                    shuffle=True, stratify=diag,
                                                    test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3a29dcb42223> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_valid, y_train, y_valid = train_test_split(imgs, diag,
#       3                                                     shuffle=True, stratify=diag,
#       4                                                     test_size=0.2, random_state=42)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2557         raise ValueError("At least one array required as input")
#    2558
# -> 2559     arrays = indexable(*arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [9200, 9160]

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d2ba684acd0f> in <cell line: 1>()
# ----> 1 X_train.shape
#
# NameError: name 'X_train' is not defined

# %%
y_train.shape
# Out:
# (7328, 5)

# %%
X_valid.shape
# Out:
# (1832, 50, 50, 3)

# %%
y_valid.shape
# Out:
# (1832, 5)

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = y_train.shape[1]

# %%
def build_net(optim):
    net = Sequential(name='DCNN')

    net.add(Conv2D(filters=16,kernel_size=(2,2),input_shape=(50, 50, 3),activation='relu',padding='same',kernel_initializer='he_normal',name='CONV_1'))
    net.add(MaxPooling2D(pool_size=(2,2), name='MAXPOOL_1'))

    net.add(Conv2D(filters=32,kernel_size=(2,2),activation='relu',padding='same',kernel_initializer='he_normal',name='CONV_2'))
    net.add(MaxPooling2D(pool_size=(2,2), name='MAXPOOL_2'))

    net.add(Conv2D(filters=64,kernel_size=(2,2),activation='relu',padding='same',kernel_initializer='he_normal',name='CONV_3'))
    net.add(MaxPooling2D(pool_size=(2,2), name='MAXPOOL_3'))

    net.add(Conv2D(filters=128,kernel_size=(2,2),activation='relu',padding='same',kernel_initializer='he_normal',name='CONV_4'))
    net.add(MaxPooling2D(pool_size=(2,2), name='MAXPOOL_4'))

    net.add(Dropout(0.2, name="DROPOUT_1"))
    net.add(Flatten(name='FLATTEN'))

    net.add(Dense(128,activation='relu',kernel_initializer='he_normal',name='DENSE_1'))

    net.add(Dense(5,activation='softmax',name='OUTPUT_LAYER'))

    net.compile(loss='categorical_crossentropy',optimizer=optim,metrics=['accuracy'])

    net.summary()

    return net

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization, LeakyReLU, Activation
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# %%
batch_size = 32
epochs = 100
optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam'),
    optimizers.Adam(),
]

model = build_net(optims[1])
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  CONV_1 (Conv2D)             (None, 50, 50, 16)        208
#
#  MAXPOOL_1 (MaxPooling2D)    (None, 25, 25, 16)        0
#
#  CONV_2 (Conv2D)             (None, 25, 25, 32)        2080
#
#  MAXPOOL_2 (MaxPooling2D)    (None, 12, 12, 32)        0
#
#  CONV_3 (Conv2D)             (None, 12, 12, 64)        8256
#
#  MAXPOOL_3 (MaxPooling2D)    (None, 6, 6, 64)          0
#
#  CONV_4 (Conv2D)             (None, 6, 6, 128)         32896
#
#  MAXPOOL_4 (MaxPooling2D)    (None, 3, 3, 128)         0
#
#  DROPOUT_1 (Dropout)         (None, 3, 3, 128)         0
#
#  FLATTEN (Flatten)           (None, 1152)              0
#
#  DENSE_1 (Dense)             (None, 128)               147584
#
#  OUTPUT_LAYER (Dense)        (None, 5)                 645
#
# =================================================================
# Total params: 191669 (748.71 KB)
# Trainable params: 191669 (748.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# !pip install visualkeras
import visualkeras
visualkeras.layered_view(model, legend=True)
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.0.2
# <PIL.Image.Image image mode=RGBA size=502x303>

# %%
history = model.fit(
    X_train, y_train, batch_size=batch_size,
    validation_data=(X_valid, y_valid),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    verbose=1
)
# Out:
# Epoch 1/100
# 229/229 [==============================] - 9s 12ms/step - loss: 1.2373 - accuracy: 0.4802 - val_loss: 1.1338 - val_accuracy: 0.5257
# Epoch 2/100
# 229/229 [==============================] - 1s 5ms/step - loss: 1.0364 - accuracy: 0.5693 - val_loss: 0.9782 - val_accuracy: 0.5901
# Epoch 3/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.9098 - accuracy: 0.6366 - val_loss: 0.8637 - val_accuracy: 0.6430
# Epoch 4/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.7796 - accuracy: 0.6976 - val_loss: 0.7379 - val_accuracy: 0.7009
# Epoch 5/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.6544 - accuracy: 0.7484 - val_loss: 0.6607 - val_accuracy: 0.7407
# Epoch 6/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.5436 - accuracy: 0.7949 - val_loss: 0.5161 - val_accuracy: 0.8182
# Epoch 7/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.4361 - accuracy: 0.8380 - val_loss: 0.4102 - val_accuracy: 0.8581
# Epoch 8/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.3775 - accuracy: 0.8619 - val_loss: 0.4563 - val_accuracy: 0.8412
# Epoch 9/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.3269 - accuracy: 0.8821 - val_loss: 0.3035 - val_accuracy: 0.9050
# Epoch 10/100
# 229/229 [==============================] - 3s 11ms/step - loss: 0.2820 - accuracy: 0.8990 - val_loss: 0.3026 - val_accuracy: 0.9045
# Epoch 11/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.2434 - accuracy: 0.9172 - val_loss: 0.2350 - val_accuracy: 0.9318
# Epoch 12/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.2164 - accuracy: 0.9279 - val_loss: 0.2275 - val_accuracy: 0.9345
# Epoch 13/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.1878 - accuracy: 0.9349 - val_loss: 0.2075 - val_accuracy: 0.9350
# Epoch 14/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1819 - accuracy: 0.9374 - val_loss: 0.2398 - val_accuracy: 0.9318
# Epoch 15/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1662 - accuracy: 0.9454 - val_loss: 0.1903 - val_accuracy: 0.9438
# Epoch 16/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1499 - accuracy: 0.9506 - val_loss: 0.2025 - val_accuracy: 0.9405
# Epoch 17/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1377 - accuracy: 0.9547 - val_loss: 0.2340 - val_accuracy: 0.9252
# Epoch 18/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1305 - accuracy: 0.9588 - val_loss: 0.1867 - val_accuracy: 0.9432
# Epoch 19/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.1221 - accuracy: 0.9581 - val_loss: 0.1640 - val_accuracy: 0.9558
# Epoch 20/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.1180 - accuracy: 0.9578 - val_loss: 0.1700 - val_accuracy: 0.9547
# Epoch 21/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1127 - accuracy: 0.9647 - val_loss: 0.1620 - val_accuracy: 0.9580
# Epoch 22/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1085 - accuracy: 0.9626 - val_loss: 0.1665 - val_accuracy: 0.9585
# Epoch 23/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.1055 - accuracy: 0.9634 - val_loss: 0.1474 - val_accuracy: 0.9547
# Epoch 24/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0918 - accuracy: 0.9667 - val_loss: 0.1738 - val_accuracy: 0.9569
# Epoch 25/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0934 - accuracy: 0.9668 - val_loss: 0.1708 - val_accuracy: 0.9563
# Epoch 26/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0949 - accuracy: 0.9655 - val_loss: 0.1428 - val_accuracy: 0.9541
# Epoch 27/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0792 - accuracy: 0.9749 - val_loss: 0.1721 - val_accuracy: 0.9552
# Epoch 28/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0899 - accuracy: 0.9693 - val_loss: 0.1832 - val_accuracy: 0.9503
# Epoch 29/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.1058 - accuracy: 0.9626 - val_loss: 0.1706 - val_accuracy: 0.9563
# Epoch 30/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.0837 - accuracy: 0.9711 - val_loss: 0.1605 - val_accuracy: 0.9602
# Epoch 31/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0871 - accuracy: 0.9682 - val_loss: 0.1417 - val_accuracy: 0.9640
# Epoch 32/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0797 - accuracy: 0.9720 - val_loss: 0.1622 - val_accuracy: 0.9602
# Epoch 33/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0742 - accuracy: 0.9718 - val_loss: 0.1454 - val_accuracy: 0.9662
# Epoch 34/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0749 - accuracy: 0.9743 - val_loss: 0.1411 - val_accuracy: 0.9656
# Epoch 35/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0736 - accuracy: 0.9738 - val_loss: 0.1545 - val_accuracy: 0.9640
# Epoch 36/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0620 - accuracy: 0.9756 - val_loss: 0.1708 - val_accuracy: 0.9623
# Epoch 37/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0559 - accuracy: 0.9779 - val_loss: 0.1691 - val_accuracy: 0.9623
# Epoch 38/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0634 - accuracy: 0.9749 - val_loss: 0.1681 - val_accuracy: 0.9574
# Epoch 39/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.0804 - accuracy: 0.9672 - val_loss: 0.1701 - val_accuracy: 0.9618
# Epoch 40/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0719 - accuracy: 0.9720 - val_loss: 0.1762 - val_accuracy: 0.9618
# Epoch 41/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0639 - accuracy: 0.9767 - val_loss: 0.1552 - val_accuracy: 0.9634
# Epoch 42/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0664 - accuracy: 0.9748 - val_loss: 0.1936 - val_accuracy: 0.9585
# Epoch 43/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0560 - accuracy: 0.9788 - val_loss: 0.1723 - val_accuracy: 0.9651
# Epoch 44/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0649 - accuracy: 0.9757 - val_loss: 0.1455 - val_accuracy: 0.9629
# Epoch 45/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0590 - accuracy: 0.9758 - val_loss: 0.1499 - val_accuracy: 0.9645
# Epoch 46/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0576 - accuracy: 0.9786 - val_loss: 0.1450 - val_accuracy: 0.9645
# Epoch 47/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0645 - accuracy: 0.9734 - val_loss: 0.1341 - val_accuracy: 0.9640
# Epoch 48/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.0519 - accuracy: 0.9786 - val_loss: 0.1361 - val_accuracy: 0.9651
# Epoch 49/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.0635 - accuracy: 0.9750 - val_loss: 0.1232 - val_accuracy: 0.9662
# Epoch 50/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0503 - accuracy: 0.9806 - val_loss: 0.1451 - val_accuracy: 0.9656
# Epoch 51/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0673 - accuracy: 0.9734 - val_loss: 0.1830 - val_accuracy: 0.9585
# Epoch 52/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0749 - accuracy: 0.9713 - val_loss: 0.2014 - val_accuracy: 0.9612
# Epoch 53/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0457 - accuracy: 0.9793 - val_loss: 0.1527 - val_accuracy: 0.9672
# Epoch 54/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0424 - accuracy: 0.9825 - val_loss: 0.1501 - val_accuracy: 0.9667
# Epoch 55/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0458 - accuracy: 0.9816 - val_loss: 0.1282 - val_accuracy: 0.9694
# Epoch 56/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0600 - accuracy: 0.9753 - val_loss: 0.1450 - val_accuracy: 0.9607
# Epoch 57/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0599 - accuracy: 0.9764 - val_loss: 0.1401 - val_accuracy: 0.9662
# Epoch 58/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.0603 - accuracy: 0.9757 - val_loss: 0.1709 - val_accuracy: 0.9651
# Epoch 59/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.0509 - accuracy: 0.9798 - val_loss: 0.1408 - val_accuracy: 0.9711
# Epoch 60/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0532 - accuracy: 0.9775 - val_loss: 0.2164 - val_accuracy: 0.9481
# Epoch 61/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0660 - accuracy: 0.9733 - val_loss: 0.1806 - val_accuracy: 0.9612
# Epoch 62/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0495 - accuracy: 0.9793 - val_loss: 0.1574 - val_accuracy: 0.9645
# Epoch 63/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0488 - accuracy: 0.9805 - val_loss: 0.1486 - val_accuracy: 0.9683
# Epoch 64/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0625 - accuracy: 0.9742 - val_loss: 0.1628 - val_accuracy: 0.9651
# Epoch 65/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0484 - accuracy: 0.9775 - val_loss: 0.1673 - val_accuracy: 0.9694
# Epoch 66/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0535 - accuracy: 0.9784 - val_loss: 0.1636 - val_accuracy: 0.9683
# Epoch 67/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0545 - accuracy: 0.9788 - val_loss: 0.1802 - val_accuracy: 0.9645
# Epoch 68/100
# 229/229 [==============================] - 2s 9ms/step - loss: 0.0410 - accuracy: 0.9816 - val_loss: 0.1539 - val_accuracy: 0.9711
# Epoch 69/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0442 - accuracy: 0.9810 - val_loss: 0.1665 - val_accuracy: 0.9640
# Epoch 70/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0508 - accuracy: 0.9786 - val_loss: 0.1569 - val_accuracy: 0.9651
# Epoch 71/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0515 - accuracy: 0.9772 - val_loss: 0.1570 - val_accuracy: 0.9634
# Epoch 72/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0586 - accuracy: 0.9779 - val_loss: 0.1571 - val_accuracy: 0.9705
# Epoch 73/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0553 - accuracy: 0.9769 - val_loss: 0.1545 - val_accuracy: 0.9678
# Epoch 74/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0477 - accuracy: 0.9803 - val_loss: 0.1721 - val_accuracy: 0.9689
# Epoch 75/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0470 - accuracy: 0.9808 - val_loss: 0.1504 - val_accuracy: 0.9689
# Epoch 76/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0456 - accuracy: 0.9808 - val_loss: 0.1536 - val_accuracy: 0.9694
# Epoch 77/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0502 - accuracy: 0.9817 - val_loss: 0.1650 - val_accuracy: 0.9662
# Epoch 78/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.0502 - accuracy: 0.9780 - val_loss: 0.1681 - val_accuracy: 0.9689
# Epoch 79/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0558 - accuracy: 0.9773 - val_loss: 0.1494 - val_accuracy: 0.9683
# Epoch 80/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0404 - accuracy: 0.9824 - val_loss: 0.1585 - val_accuracy: 0.9667
# Epoch 81/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0348 - accuracy: 0.9842 - val_loss: 0.1834 - val_accuracy: 0.9651
# Epoch 82/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0419 - accuracy: 0.9827 - val_loss: 0.1532 - val_accuracy: 0.9689
# Epoch 83/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0373 - accuracy: 0.9832 - val_loss: 0.1514 - val_accuracy: 0.9700
# Epoch 84/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0527 - accuracy: 0.9772 - val_loss: 0.1938 - val_accuracy: 0.9585
# Epoch 85/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0653 - accuracy: 0.9760 - val_loss: 0.1500 - val_accuracy: 0.9662
# Epoch 86/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0568 - accuracy: 0.9763 - val_loss: 0.1336 - val_accuracy: 0.9678
# Epoch 87/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.0344 - accuracy: 0.9849 - val_loss: 0.1412 - val_accuracy: 0.9634
# Epoch 88/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.0366 - accuracy: 0.9829 - val_loss: 0.1295 - val_accuracy: 0.9722
# Epoch 89/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.0497 - accuracy: 0.9786 - val_loss: 0.1537 - val_accuracy: 0.9612
# Epoch 90/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0381 - accuracy: 0.9838 - val_loss: 0.1490 - val_accuracy: 0.9716
# Epoch 91/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0356 - accuracy: 0.9838 - val_loss: 0.1805 - val_accuracy: 0.9607
# Epoch 92/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0579 - accuracy: 0.9768 - val_loss: 0.1919 - val_accuracy: 0.9667
# Epoch 93/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0425 - accuracy: 0.9823 - val_loss: 0.1604 - val_accuracy: 0.9683
# Epoch 94/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0385 - accuracy: 0.9832 - val_loss: 0.1942 - val_accuracy: 0.9623
# Epoch 95/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0579 - accuracy: 0.9764 - val_loss: 0.1525 - val_accuracy: 0.9683
# Epoch 96/100
# 229/229 [==============================] - 2s 8ms/step - loss: 0.0494 - accuracy: 0.9803 - val_loss: 0.1528 - val_accuracy: 0.9662
# Epoch 97/100
# 229/229 [==============================] - 2s 7ms/step - loss: 0.0347 - accuracy: 0.9838 - val_loss: 0.1303 - val_accuracy: 0.9738
# Epoch 98/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0331 - accuracy: 0.9849 - val_loss: 0.1542 - val_accuracy: 0.9727
# Epoch 99/100
# 229/229 [==============================] - 1s 6ms/step - loss: 0.0399 - accuracy: 0.9831 - val_loss: 0.1853 - val_accuracy: 0.9656
# Epoch 100/100
# 229/229 [==============================] - 1s 5ms/step - loss: 0.0618 - accuracy: 0.9743 - val_loss: 0.1676 - val_accuracy: 0.9591

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history.epoch, y=history.history['accuracy'], label='train')
sns.lineplot(x=history.epoch, y=history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history.epoch, y=history.history['loss'], label='train')
sns.lineplot(x=history.epoch, y=history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()

print("Final Accuracy of emotion after 6 epochs will be: ", round(history.history['accuracy'][99]*100,2), "%")
# Out:
# Final Accuracy of emotion after 6 epochs will be:  97.43 %

# %%
# !pip install scikit-plot

import scikitplot

predict_x=model.predict(X_valid)
yhat_valid=np.argmax(predict_x,axis=1)
scikitplot.metrics.plot_confusion_matrix(np.argmax(y_valid, axis=1), yhat_valid, figsize=(7,7))
pyplot.savefig("confusion_matrix_dcnn.png")
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7
# 58/58 [==============================] - 0s 2ms/step

# %%
# Assuming you're using TensorFlow or Keras
from tensorflow.keras.models import save_model

# Save the model to disk
model.save('Model.h5')

# Optionally, you can also save the model architecture to a JSON file
model_json = model.to_json()
with open("model1.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import classification_report

print(f'total wrong validation predictions: {np.sum(np.argmax(y_valid, axis=1) != yhat_valid)}\n\n')
print(classification_report(np.argmax(y_valid, axis=1), yhat_valid))
# Out:
# total wrong validation predictions: 75
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       361
#            1       0.96      0.99      0.98       370
#            2       0.97      0.91      0.94       400
#            3       0.95      0.98      0.96       347
#            4       0.92      0.97      0.95       354
#
#     accuracy                           0.96      1832
#    macro avg       0.96      0.96      0.96      1832
# weighted avg       0.96      0.96      0.96      1832

# %%
def build_alexnet(optim):
    net = Sequential(name='AlexNet')

    # 1st convolutional layer
    net.add(Conv2D(96, (11, 11), strides=(4, 4), padding='same', activation='relu', name='CONV_1'))

    # 2nd max pooling layer
    net.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='MAXPOOL_1'))

    # 3rd convolutional layer
    net.add(Conv2D(256, (5, 5), strides=(1, 1), padding='same', activation='relu', name='CONV_2'))

    # 4th max pooling layer
    net.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='MAXPOOL_2'))

    # 5th convolutional layer
    net.add(Conv2D(384, (3, 3), strides=(1, 1), padding='same', activation='relu', name='CONV_3'))

    # 6th convolutional layer
    net.add(Conv2D(384, (3, 3), strides=(1, 1), padding='same', activation='relu', name='CONV_4'))

    # 7th convolutional layer
    net.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu', name='CONV_5'))

    # 8th max pooling layer
    net.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='MAXPOOL_3'))

    # 1st fully connected layer
    net.add(Flatten(name='FLATTEN'))
    net.add(Dense(4096, activation='relu', name='DENSE_1'))

    # 2nd fully connected layer
    net.add(Dense(4096, activation='relu', name='DENSE_2'))

    # 3rd fully connected layer
    net.add(Dense(5, activation='softmax', name='OUTPUT_LAYER'))

    net.compile(loss='categorical_crossentropy',optimizer=optim,metrics=['accuracy'])

#     net.summary()

    return net

# %%
batch_size = 16
epochs = 100
optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam'),
    optimizers.Adam(),
]

model_alex = build_alexnet(optims[1])

# %%
history_2 = model_alex.fit(
    X_train, y_train, batch_size=batch_size,
    validation_data=(X_valid, y_valid),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    verbose=1
)
# Out:
# Epoch 1/100
# 458/458 [==============================] - 10s 16ms/step - loss: 1.4334 - accuracy: 0.3068 - val_loss: 1.2808 - val_accuracy: 0.3854
# Epoch 2/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.2736 - accuracy: 0.4419 - val_loss: 1.2499 - val_accuracy: 0.4776
# Epoch 3/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.2050 - accuracy: 0.4850 - val_loss: 1.1894 - val_accuracy: 0.4918
# Epoch 4/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.1809 - accuracy: 0.5003 - val_loss: 1.1940 - val_accuracy: 0.5175
# Epoch 5/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.1617 - accuracy: 0.5113 - val_loss: 1.1960 - val_accuracy: 0.4989
# Epoch 6/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.1395 - accuracy: 0.5225 - val_loss: 1.1370 - val_accuracy: 0.5197
# Epoch 7/100
# 458/458 [==============================] - 7s 14ms/step - loss: 1.1209 - accuracy: 0.5348 - val_loss: 1.1830 - val_accuracy: 0.5093
# Epoch 8/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.1044 - accuracy: 0.5438 - val_loss: 1.1221 - val_accuracy: 0.5382
# Epoch 9/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.0841 - accuracy: 0.5493 - val_loss: 1.0679 - val_accuracy: 0.5306
# Epoch 10/100
# 458/458 [==============================] - 7s 16ms/step - loss: 1.0541 - accuracy: 0.5576 - val_loss: 1.0159 - val_accuracy: 0.5753
# Epoch 11/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.0374 - accuracy: 0.5742 - val_loss: 1.0495 - val_accuracy: 0.5568
# Epoch 12/100
# 458/458 [==============================] - 7s 16ms/step - loss: 0.9973 - accuracy: 0.5899 - val_loss: 1.0420 - val_accuracy: 0.5660
# Epoch 13/100
# 458/458 [==============================] - 7s 15ms/step - loss: 0.9699 - accuracy: 0.5969 - val_loss: 1.1260 - val_accuracy: 0.5884
# Epoch 14/100
# 458/458 [==============================] - 7s 16ms/step - loss: 0.9199 - accuracy: 0.6216 - val_loss: 0.9107 - val_accuracy: 0.6283
# Epoch 15/100
# 458/458 [==============================] - 7s 15ms/step - loss: 0.8757 - accuracy: 0.6438 - val_loss: 0.8389 - val_accuracy: 0.6337
# Epoch 16/100
# 458/458 [==============================] - 7s 15ms/step - loss: 1.1564 - accuracy: 0.5352 - val_loss: 1.0346 - val_accuracy: 0.5524
# Epoch 17/100
# 458/458 [==============================] - 7s 15ms/step - loss: 0.9427 - accuracy: 0.6066 - val_loss: 0.8870 - val_accuracy: 0.6277
# Epoch 18/100
# 458/458 [==============================] - 7s 15ms/step - loss: 0.8324 - accuracy: 0.6565 - val_loss: 0.7680 - val_accuracy: 0.6829
# Epoch 19/100
# 458/458 [==============================] - 7s 15ms/step - loss: 0.7796 - accuracy: 0.6880 - val_loss: 0.7798 - val_accuracy: 0.6741
# Epoch 20/100
# 458/458 [==============================] - 7s 14ms/step - loss: 0.7301 - accuracy: 0.7065 - val_loss: 0.7728 - val_accuracy: 0.6818
# Epoch 21/100
# 458/458 [==============================] - 7s 16ms/step - loss: 0.7080 - accuracy: 0.7133 - val_loss: 0.7152 - val_accuracy: 0.6987
# Epoch 22/100
# 458/458 [==============================] - 7s 15ms/step - loss: 0.6389 - accuracy: 0.7388 - val_loss: 0.6943 - val_accuracy: 0.7145
# Epoch 23/100
# 432/458 [===========================>..] - ETA: 0s - loss: 0.6342 - accuracy: 0.7468

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_2.epoch, y=history_2.history['accuracy'], label='train')
sns.lineplot(x=history_2.epoch, y=history_2.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_2.epoch, y=history_2.history['loss'], label='train')
sns.lineplot(x=history_2.epoch, y=history_2.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()

print("Final Accuracy of emotion after 6 epochs will be: ", round(history_2.history['accuracy'][99]*100,2), "%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-4300d6274a31> in <cell line: 5>()
#       3
#       4 ax = pyplot.subplot(1, 2, 1)
# ----> 5 sns.lineplot(x=history_2.epoch, y=history_2.history['accuracy'], label='train')
#       6 sns.lineplot(x=history_2.epoch, y=history_2.history['val_accuracy'], label='valid')
#       7 pyplot.title('Accuracy')
#
# NameError: name 'history_2' is not defined

# %%
import scikitplot

predict_x=model_alex.predict(X_valid)
yhat_valid=np.argmax(predict_x,axis=1)
scikitplot.metrics.plot_confusion_matrix(np.argmax(y_valid, axis=1), yhat_valid, figsize=(7,7))
pyplot.savefig("confusion_matrix_dcnn.png")
# Out:
# 58/58 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import classification_report

print(f'total wrong validation predictions: {np.sum(np.argmax(y_valid, axis=1) != yhat_valid)}\n\n')
print(classification_report(np.argmax(y_valid, axis=1), yhat_valid))
# Out:
# total wrong validation predictions: 133
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94       361
#            1       0.92      0.98      0.95       370
#            2       0.92      0.88      0.90       400
#            3       0.93      0.93      0.93       347
#            4       0.90      0.94      0.92       354
#
#     accuracy                           0.93      1832
#    macro avg       0.93      0.93      0.93      1832
# weighted avg       0.93      0.93      0.93      1832
